# %% [markdown]
# <a href="https://colab.research.google.com/github/raimandvi/python_oops/blob/main/constructor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Constructor in Python
#
# A constructor is a special method that is automatically called when an object of a class is created.

# %% [markdown]
# **1. __init__ Method**
#
#
#
# *   Automatically executed
# *   No need to call manually

# %%
class student:
  def __init__(self):
    print("Constructor is called")


s1 = student()
# Out:
# Constructor is called

# %% [markdown]
# **2. Constructor with Attributes**

# %%
class Student:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def show_details(self):
    print("Name:", self.name)
    print("Age:", self.age)

s1 = Student("Mansi", 22)
s2 = Student("Rahul", 25)

s1.show_details()
s2.show_details()
# Out:
# Name: Mansi
# Age: 22
# Name: Rahul
# Age: 25
